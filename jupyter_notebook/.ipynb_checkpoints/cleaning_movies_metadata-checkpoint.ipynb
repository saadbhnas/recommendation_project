# %%
import pandas as pd 
import os
import json
import numpy as np
import ast
import nltk
import re
pd.options.display.max_columns=40
from sklearn.base import TransformerMixin , BaseEstimator

# %%
data = pd.read_csv(r'C:\Users\saadb\recommendation_project\recommendation_model\dataset\movies_metadata.csv',low_memory=False,date_parser='release_date')

# %%
data.head(3)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...
# 1           Jumanji  When siblings Judy and Peter discover an encha...
# 2  Grumpier Old Men  A family wedding reignites the ancient feud be...
#
#   popularity                       poster_path  \
# 0  21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1  17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2    11.7129  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
#
#                                 production_countries release_date  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
#
#        revenue  runtime                                   spoken_languages  \
# 0  373554033.0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0    101.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
#
#               title  video  vote_average  vote_count
# 0         Toy Story  False           7.7      5415.0
# 1           Jumanji  False           6.9      2413.0
# 2  Grumpier Old Men  False           6.5        92.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
data.shape
# Out:
# (45466, 24)

# %%
data.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# initial thoughts about data :-
# -irrelevant columns ( id - imdb_id - homepage - poster_path ) id maybe useable if needed to merge data
# -columns ( belongs_to_collection - tagline ) have a lot of missing data inspect to see what is the reason and how to deal with it

# %%
#dropping irrelevant columns 
data.drop(['imdb_id','homepage','poster_path'],axis=1,inplace=True)

# %%
#nothing suspicious about belongs to collection having so much nans 
data[data['belongs_to_collection'].isnull()].head()
# Out:
#    adult belongs_to_collection    budget  \
# 1  False                   NaN  65000000
# 3  False                   NaN  16000000
# 5  False                   NaN  60000000
# 6  False                   NaN  58000000
# 7  False                   NaN         0
#
#                                               genres     id original_language  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    949                en
# 6  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...  11860                en
# 7  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  45325                en
#
#       original_title                                           overview  \
# 1            Jumanji  When siblings Judy and Peter discover an encha...
# 3  Waiting to Exhale  Cheated on, mistreated and stepped on, the wom...
# 5               Heat  Obsessive master thief, Neil McCauley leads a ...
# 6            Sabrina  An ugly duckling having undergone a remarkable...
# 7       Tom and Huck  A mischievous young boy, Tom Sawyer, witnesses...
#
#   popularity                               production_companies  \
# 1  17.015539  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 3   3.859495  [{'name': 'Twentieth Century Fox Film Corporat...
# 5  17.924927  [{'name': 'Regency Enterprises', 'id': 508}, {...
# 6   6.677277  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 7   2.561161        [{'name': 'Walt Disney Pictures', 'id': 2}]
#
#                                 production_countries release_date  \
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 5  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 6  [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   1995-12-15
# 7  [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
#
#        revenue  runtime                                   spoken_languages  \
# 1  262797249.0    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 3   81452156.0    127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 5  187436818.0    170.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 6          0.0    127.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 7          0.0     97.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                            tagline  \
# 1  Released          Roll the dice and unleash the excitement!
# 3  Released  Friends are the people who let you be yourself...
# 5  Released                           A Los Angeles Crime Saga
# 6  Released  You are cordially invited to the most surprisi...
# 7  Released                             The Original Bad Boys.
#
#                title  video  vote_average  vote_count
# 1            Jumanji  False           6.9      2413.0
# 3  Waiting to Exhale  False           6.1        34.0
# 5               Heat  False           7.7      1886.0
# 6            Sabrina  False           6.2       141.0
# 7       Tom and Huck  False           5.4        45.0

# %%
json.loads(data['belongs_to_collection'][0].replace("'",'"'))
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
# function to handle json data replacing "" and '' as json format should be and then use json.loads and if anything went 
#wrong or some addidtion error like i have visuilized values like nan instead of json dict we replace those with np.nan
def handle_json(x):
    try :
        
        x = x.replace("'",'"')
    
        x = json.loads(x)
        
    except :
        return np.nan
    
    return x

# %%
#apply handle_json to 'belongs_to_collection' 
data['belongs_to_collection'] = data['belongs_to_collection'].apply(lambda x : handle_json(x))

# %%
#action may improve performance 
#notice that number of nan values increased i was expecting that number of nans will be equal to the number showen above from  
# info function after printing number of nan of all columns this number increased by 1323 need to investigate more in this 
data['belongs_to_collection'].isnull().value_counts()
# Out:
# True     42295
# False     3171
# Name: belongs_to_collection, dtype: int64

# %%
#extracting collection name from 'belongs_to_collection' as the useful information about this feature 
data['belongs_to_collection'].apply(lambda x : x['name'] if isinstance(x,dict) else np.nan)
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 45461                               NaN
# 45462                               NaN
# 45463                               NaN
# 45464                               NaN
# 45465                               NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
data['belongs_to_collection'] = data['belongs_to_collection'].apply(lambda x : x['name'] if isinstance(x,dict) else np.nan)

# %%
# for genres we need to extract all possible genres from multiple dict same concept to deal with json format but to get the 
# useful final form of the feature will need to modify code used for extraction 
data['genres'][0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
#dealng with json format 
data['genres'] = data['genres'].apply(lambda x : handle_json(x))

# %%
# used code from course on udemy for the join idea 
data['genres'].apply(lambda x : '|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)
# Out:
# 0         Animation|Comedy|Family
# 1        Adventure|Fantasy|Family
# 2                  Romance|Comedy
# 3            Comedy|Drama|Romance
# 4                          Comedy
#                    ...
# 45461                Drama|Family
# 45462                       Drama
# 45463       Action|Drama|Thriller
# 45464
# 45465
# Name: genres, Length: 45466, dtype: object

# %%
data['genres'] = data['genres'].apply(lambda x : '|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
# for language column numbers are being counted as language and i think this is not valid 
data['original_language'].value_counts().tail(25)
# Out:
# lo       2
# mn       2
# pa       2
# iu       2
# af       2
# 82.0     1
# cy       1
# sm       1
# hy       1
# uz       1
# 68.0     1
# gl       1
# lb       1
# mt       1
# rw       1
# fy       1
# ay       1
# eo       1
# tg       1
# jv       1
# zu       1
# qu       1
# 104.0    1
# la       1
# si       1
# Name: original_language, dtype: int64

# %% [markdown]
# # so they are string i think to get the numbers we can use nltk and use that to eliminate number like string or we can iterte
# # over every row in language column and chech if it contain number

# %%
x=[]
for ele in data['original_language'].dropna():
    results = re.findall('[0-9]+',ele)
    if results:
        x.append(results[0])

# %%
x
# Out:
# ['104', '68', '82']

# %%
#so after extracting numbers that was parsed as strings using re we can remove them but they are represented in float format 
# and we captured integer format thats why '.0' is added to them 
for i in x:
    i = i + '.0'
    data['original_language'].replace(i,np.nan,inplace=True)

# %%
#i need to see the duplicate if they are movies remake
data['original_title'].value_counts()
# Out:
# Hamlet                 8
# Alice in Wonderland    8
# Les Misérables         7
# Cinderella             7
# Macbeth                7
#                       ..
# 거미숲                    1
# What Goes Up           1
# 12th & Delaware        1
# Wonder Bar             1
# Queerama               1
# Name: original_title, Length: 43373, dtype: int64

# %%
#incpecting hamlet for example
hamlet = data[(data['original_title']=='Hamlet')]

# %%
#as we see they are the same tilte but different movies so movie remade 
hamlet
# Out:
#        adult belongs_to_collection   budget         genres      id  \
# 1360   False                   NaN        0          Drama   10549
# 1832   False                   NaN   750000          Drama   23383
# 3476   False                   NaN  2000000          Drama   10688
# 3601   False                   NaN        0  Drama|History   10264
# 13313  False                   NaN        0          Drama  125705
# 18061  False                   NaN        0          Drama   42605
# 18908  False                   NaN        0          Drama   28238
# 21239  False                   NaN        0          Drama  106848
#
#       original_language original_title  \
# 1360                 en         Hamlet
# 1832                 en         Hamlet
# 3476                 en         Hamlet
# 3601                 en         Hamlet
# 13313                en         Hamlet
# 18061                en         Hamlet
# 18908                en         Hamlet
# 21239                en         Hamlet
#
#                                                 overview popularity  \
# 1360   Hamlet, Prince of Denmark, returns home to fin...   9.994088
# 1832   Winner of four Academy Awards, including Best ...   3.188067
# 3476   Modern day adaptation of Shakespeare's immorta...  12.896203
# 3601   Hamlet, Prince of Denmark, finds out that his ...   12.50303
# 13313                           To be or not to be, etc.   0.584251
# 18061  Tony Richardson's Hamlet is based on his own s...   0.873375
# 18908  David Tennant stars in a film of the Royal Sha...   1.682371
# 21239  Hamlet comes home from university to find his ...    0.48737
#
#                                     production_companies  \
# 1360   [{'name': 'Castle Rock Entertainment', 'id': 9...
# 1832          [{'name': 'Two Cities Films', 'id': 4006}]
# 3476   [{'name': 'Miramax Films', 'id': 14}, {'name':...
# 3601   [{'name': 'Icon Productions', 'id': 152}, {'na...
# 13313   [{'name': 'Hallmark Entertainment', 'id': 4056}]
# 18061  [{'name': 'Columbia Pictures Corporation', 'id...
# 18908  [{'name': 'NHK Enterprises', 'id': 11376}, {'n...
# 21239                                                 []
#
#                                     production_countries release_date  \
# 1360   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   1996-12-25
# 1832    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   1948-03-25
# 3476   [{'iso_3166_1': 'US', 'name': 'United States o...   2000-05-12
# 3601   [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...   1990-12-19
# 13313  [{'iso_3166_1': 'US', 'name': 'United States o...   2000-12-10
# 18061   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   1969-12-21
# 18908  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2009-12-26
# 21239                                                 []   1980-05-25
#
#           revenue  runtime                          spoken_languages  \
# 1360          0.0    242.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 1832          0.0    155.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 3476    1568749.0    112.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 3601   20710451.0    130.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 13313         0.0    178.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 18061         0.0    117.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 18908         0.0    185.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 21239         0.0    210.0                                        []
#
#          status                                            tagline   title  \
# 1360   Released                                                NaN  Hamlet
# 1832   Released                                                NaN  Hamlet
# 3476   Released  Passion, Betrayal, Revenge, A hostile takeover...  Hamlet
# 3601   Released  The extraordinary adaptation of Shakespeare's ...  Hamlet
# 13313  Released                                                NaN  Hamlet
# 18061  Released                                 From the author of  Hamlet
# 18908  Released                               To be, or not to be?  Hamlet
# 21239  Released                                                NaN  Hamlet
#
#        video  vote_average  vote_count
# 1360   False           7.3       118.0
# 1832   False           7.1        48.0
# 3476   False           6.0        35.0
# 3601   False           6.7        95.0
# 13313  False           0.0         0.0
# 18061  False           6.1         7.0
# 18908  False           7.3        22.0
# 21239  False           4.0         3.0

# %%
#here i can replace 'No overview found' , 'No Overview' , 'No movie overview available' and blancks with 'missing'
data['overview'].value_counts()
# Out:
# No overview found.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       133
# No Overview                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                7
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            5
# No movie overview available.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               3
# A few funny little novels about different aspects of life.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 3
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# "Of Time and The City" is both a love song and a eulogy to the director's birthplace of Liverpool, England. It is also a response to memory, reflection and the experience of losing a sense of place as the skyline changes and time takes it toll. The visual content of the film consists largely of archival clips of Liverpool from the 1940s to the 1960s, their nostalgic charm darkened by accompanying music and by the counterpoint of Davies’ dry, at times dyspeptic, voice-over narration. His voice thickens with emotion as he recalls the delights of juvenile movie-going or the ritual of a holiday trip to New Brighton, across the River Mersey, and hardens with contempt when he turns his gaze on the hoopla surrounding Queen Elizabeth’s coronation in 1953.      1
# We are in the year 1871. A journalist for Versailles Television broadcasts a soothing and official view of events while a Commune television is set up to provide the perspectives of the Paris rebels. On a stage-like set, more than 200 actors interpret characters of the Commune, especially the Popincourt neighbourhood in the XIth arrondissement. They voice their own thoughts and feelings concerning the social and political reforms. The scenes consist mainly of long camera takes.                                                                                                                                                                                                                                                                                         1
# A kindergarten director Troshkin is a dead ringer for a criminal nicknamed "Docent" who stole the priceless...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# A man wakes up deep inside a cave. Suffering amnesia, he has no recollection of how he came to be here or of what happened to the man whose body he finds beside him. Tailed by a mysterious creature, he must continue through this strange and fantastic world. Enclosed, Tolbiac has no other option to reach the surface than to use REZO ZERO, secret observing cells in this cemetery-like abandoned mine.                                                                                                                                                                                                                                                                                                                                                                           1
# 50 years after decriminalisation of homosexuality in the UK, director Daisy Asquith mines the jewels of the BFI archive to take us into the relationships, desires, fears and expressions of gay men and women in the 20th century.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Name: overview, Length: 44307, dtype: int64

# %%
strings_to_replace_overview = ['No overview found.' , 'No Overview' , 'No movie overview available', ' ','No movie overview available.']
for ele in strings_to_replace_overview:
    data['overview'].replace(ele,'missing',inplace=True)

# %%
data['overview'].value_counts(ascending=False)
# Out:
# missing                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  148
# King Lear, old and tired, divides his kingdom among his daughters, giving great importance to their protestations of love for him. When Cordelia, youngest and most honest, refuses to idly flatter the old man in return for favor, he banishes her and turns for support to his remaining daughters. But Goneril and Regan have no love for him and instead plot to take all his power from him. In a parallel, Lear's loyal courtier Gloucester favors his illegitimate son Edmund after being told lies about his faithful son Edgar. Madness and tragedy befall both ill-starred fathers.                                                                                                                                                                                             3
# Released                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   3
# Adaptation of the Jane Austen novel.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       3
# Recovering from a nail gun shot to the head and 13 months of coma, doctor Pekka Valinta starts to unravel the mystery of his past, still suffering from total amnesia.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     3
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# "Of Time and The City" is both a love song and a eulogy to the director's birthplace of Liverpool, England. It is also a response to memory, reflection and the experience of losing a sense of place as the skyline changes and time takes it toll. The visual content of the film consists largely of archival clips of Liverpool from the 1940s to the 1960s, their nostalgic charm darkened by accompanying music and by the counterpoint of Davies’ dry, at times dyspeptic, voice-over narration. His voice thickens with emotion as he recalls the delights of juvenile movie-going or the ritual of a holiday trip to New Brighton, across the River Mersey, and hardens with contempt when he turns his gaze on the hoopla surrounding Queen Elizabeth’s coronation in 1953.      1
# We are in the year 1871. A journalist for Versailles Television broadcasts a soothing and official view of events while a Commune television is set up to provide the perspectives of the Paris rebels. On a stage-like set, more than 200 actors interpret characters of the Commune, especially the Popincourt neighbourhood in the XIth arrondissement. They voice their own thoughts and feelings concerning the social and political reforms. The scenes consist mainly of long camera takes.                                                                                                                                                                                                                                                                                         1
# A kindergarten director Troshkin is a dead ringer for a criminal nicknamed "Docent" who stole the priceless...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# A man wakes up deep inside a cave. Suffering amnesia, he has no recollection of how he came to be here or of what happened to the man whose body he finds beside him. Tailed by a mysterious creature, he must continue through this strange and fantastic world. Enclosed, Tolbiac has no other option to reach the surface than to use REZO ZERO, secret observing cells in this cemetery-like abandoned mine.                                                                                                                                                                                                                                                                                                                                                                           1
# 50 years after decriminalisation of homosexuality in the UK, director Daisy Asquith mines the jewels of the BFI archive to take us into the relationships, desires, fears and expressions of gay men and women in the 20th century.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Name: overview, Length: 44304, dtype: int64

# %%
data['popularity'].value_counts(ascending=False)
# Out:
# 0.0         66
# 1e-06       56
# 0.000308    43
# 0.00022     40
# 0.001177    38
#             ..
# 4.762242     1
# 6.173752     1
# 0.645652     1
# 0.556292     1
# 0.163015     1
# Name: popularity, Length: 43758, dtype: int64

# %%
data['popularity'].replace('Beware Of Frost Bites',np.nan,inplace=True)

# %%
string_popularity_no_floats = [x for x in data['popularity'] if not isinstance(x,float)]

# %%
string_popularity = [x for x in string_popularity_no_floats if re.search('[a-zA-Z]', x)]

# %%
string_popularity
# Out:
# ['8.2e-05',
#  '4e-06',
#  '1.7e-05',
#  '1e-06',
#  '6e-06',
#  '1e-06',
#  '3.3e-05',
#  '1e-06',
#  '3.8e-05',
#  '1e-06',
#  '5.9e-05',
#  '1e-06',
#  '1e-06',
#  '2.1e-05',
#  '1e-06',
#  '7e-06',
#  '1.3e-05',
#  '5e-06',
#  '8.8e-05',
#  '1e-06',
#  '1e-06',
#  '4e-06',
#  '8e-06',
#  '1.1e-05',
#  '2.1e-05',
#  '3.8e-05',
#  '3e-06',
#  '1.8e-05',
#  '3.1e-05',
#  '4.2e-05',
#  '2e-06',
#  '7.4e-05',
#  '4.1e-05',
#  '1.8e-05',
#  '9.1e-05',
#  '8e-06',
#  '6.9e-05',
#  '1e-06',
#  '2.4e-05',
#  '1e-06',
#  '1.1e-05',
#  '1e-06',
#  '3e-06',
#  '9.4e-05',
#  '3.8e-05',
#  '8e-06',
#  '1e-06',
#  '1e-06',
#  '8e-06',
#  '8.2e-05',
#  '4.4e-05',
#  '2.3e-05',
#  '1e-05',
#  '3.9e-05',
#  '1e-06',
#  '1e-06',
#  '2e-06',
#  '4e-05',
#  '1.1e-05',
#  '1.5e-05',
#  '1.3e-05',
#  '7.4e-05',
#  '1e-06',
#  '4.9e-05',
#  '9.5e-05',
#  '1e-06',
#  '1e-06',
#  '1e-06',
#  '5.7e-05',
#  '3e-06',
#  '1e-06',
#  '1.8e-05',
#  '3e-06',
#  '2.1e-05',
#  '1e-06',
#  '1e-06',
#  '3.2e-05',
#  '1e-06',
#  '1e-06',
#  '2e-06',
#  '5.3e-05',
#  '1e-06',
#  '2.1e-05',
#  '1e-06',
#  '4.8e-05',
#  '7.3e-05',
#  '1e-06',
#  '1.1e-05',
#  '1e-06',
#  '6e-05',
#  '9e-06',
#  '7.3e-05',
#  '1e-06',
#  '1e-06',
#  '1e-06',
#  '1e-06',
#  '1e-06',
#  '8e-06',
#  '1e-06',
#  '4e-06',
#  '1e-06',
#  '4e-06',
#  '1e-06',
#  '1e-06',
#  '3.6e-05',
#  '2e-06',
#  '6.2e-05',
#  '3.8e-05',
#  '1.9e-05',
#  '1e-06',
#  '2.6e-05',
#  '4.3e-05',
#  '1e-06',
#  '3.5e-05',
#  '3.5e-05',
#  '9e-06',
#  '9.4e-05',
#  '1e-06',
#  '1.1e-05',
#  '1e-06',
#  '2.5e-05',
#  '1e-06',
#  '2.3e-05',
#  '2e-06',
#  '1e-06',
#  '5e-05',
#  '6e-06',
#  '4.2e-05',
#  '2.1e-05',
#  '1e-06',
#  '1e-06',
#  '8e-06',
#  '1e-06',
#  '8e-05',
#  '1e-06',
#  '1e-06',
#  '2.5e-05',
#  '1e-06',
#  '4e-06',
#  '1.5e-05',
#  '1e-06',
#  '6e-06',
#  '1e-06',
#  '1e-06',
#  '6e-06',
#  '2.2e-05',
#  '2.9e-05',
#  '3e-06',
#  '5e-05',
#  '1e-06',
#  '1e-06',
#  '3e-06',
#  '1e-06',
#  '2e-06',
#  '3.5e-05']

# %% [markdown]
# after reviwing popularity values noticed that we have 66 movie with 0.0 popularity and this seem odd somehow tried to view those movies but couldnt becuase the numbers are strings and cant convert them to floats becuase we have string also 'Beware Of Frost Bites' i captured by regular expressions so i need to remove or replace 'Beware Of Frost Bites' by nan and convert popularity type to float and inspect the odd popularities so after inspecting the 0.0 popularity thier is relationship i think between missing values in most of columns and the 0.0 popularity we can maybe remove or drop these rows.

# %%
data['popularity'] = data['popularity'].astype(float)

# %%
index_of_zero_popularity = data[(data['popularity']==0.0)].index

# %%
data.drop(index_of_zero_popularity , axis=0 ,inplace=True)

# %%
index_of_zero_popularity
# Out:
# Int64Index([], dtype='int64')

# %%
# from 'production_companies' column i only need name so i can try extract that 
data['production_companies'][1]
# Out:
# "[{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Teitler Film', 'id': 2550}, {'name': 'Interscope Communications', 'id': 10201}]"

# %%
#here missing values represented by empty list []
data['production_companies'].value_counts(ascending=False)
# Out:
# []                                                                                                                                                                                                                                                                                                                                                      11817
# [{'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 8411}]                                                                                                                                                                                                                                                                                                       742
# [{'name': 'Warner Bros.', 'id': 6194}]                                                                                                                                                                                                                                                                                                                    540
# [{'name': 'Paramount Pictures', 'id': 4}]                                                                                                                                                                                                                                                                                                                 504
# [{'name': 'Twentieth Century Fox Film Corporation', 'id': 306}]                                                                                                                                                                                                                                                                                           439
#                                                                                                                                                                                                                                                                                                                                                         ...
# [{'name': 'HBO Films', 'id': 7429}, {'name': 'Moving Pictures', 'id': 15888}]                                                                                                                                                                                                                                                                               1
# [{'name': 'BIM Distribuzione', 'id': 225}, {'name': 'Canal+', 'id': 5358}, {'name': 'Alta Producción', 'id': 10011}, {'name': 'Centre National de la Cinématographie (CNC)', 'id': 18367}, {'name': 'Rézo Productions', 'id': 30231}, {'name': 'Compagnie Eric Rohmer (CER)', 'id': 30232}, {'name': 'Cinémage', 'id': 30233}]                              1
# [{'name': 'Galatée Films', 'id': 793}, {'name': 'Novo Arturo Films', 'id': 1168}, {'name': 'Constantin Film Produktion', 'id': 5755}, {'name': 'Pathé', 'id': 7981}, {'name': 'France 2 Cinéma', 'id': 15671}, {'name': 'France 3 Cinema', 'id': 16804}, {'name': 'Logline Studios', 'id': 23066}, {'name': 'Blue Screen Productions', 'id': 23067}]        1
# [{'name': 'Fox Searchlight Pictures', 'id': 43}, {'name': '26 Films', 'id': 2157}]                                                                                                                                                                                                                                                                          1
# [{'name': 'Yermoliev', 'id': 88753}]                                                                                                                                                                                                                                                                                                                        1
# Name: production_companies, Length: 22703, dtype: int64

# %%
data['production_companies'] = data['production_companies'].apply(lambda x : handle_json(x))

# %%
data['production_companies'][1][0]['name']
# Out:
# 'TriStar Pictures'

# %%
data['production_companies'] = data['production_companies'].apply(lambda x : '|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
data['production_countries'][0]
# Out:
# "[{'iso_3166_1': 'US', 'name': 'United States of America'}]"

# %%
data['production_countries'] = data['production_countries'].apply(lambda x : handle_json(x))

# %%
data['production_countries'] = data['production_countries'].apply(lambda x : '|'.join(i['name'] for i in x) if isinstance(x,list) else np.nan)

# %%
#missing values represented here by empty space we need to replace that with 'missing' 
data['production_countries'].value_counts(ascending=False)
# Out:
# United States of America                17845
#                                          6237
# United Kingdom                           2236
# France                                   1653
# Japan                                    1355
#                                         ...
# Australia|South Africa                      1
# Romania|United Kingdom|Canada               1
# Finland|Germany|Netherlands                 1
# France|Denmark|Spain|Sweden                 1
# Egypt|Italy|United States of America        1
# Name: production_countries, Length: 2385, dtype: int64

# %%
data['production_countries'].replace('' , 'missing', inplace=True)

# %%
#for budget column we have a lot of values with 0 budget and this is not true or vlad value so we can replace these values with 
#np.nan
data['budget'].value_counts(ascending=False)
# Out:
# 0           36509
# 5000000       286
# 10000000      259
# 20000000      243
# 2000000       242
#             ...
# 923             1
# 72500000        1
# 2160000         1
# 4439832         1
# 1254040         1
# Name: budget, Length: 1226, dtype: int64

# %%
#thier is not a lot of missing values crossponding to 0 budget so we can just replace them with np.nan
data[(data['budget']=='0')]
# Out:
#        adult           belongs_to_collection budget  \
# 2      False       Grumpy Old Men Collection      0
# 4      False  Father of the Bride Collection      0
# 7      False                             NaN      0
# 11     False                             NaN      0
# 12     False                Balto Collection      0
# ...      ...                             ...    ...
# 45461  False                             NaN      0
# 45462  False                             NaN      0
# 45463  False                             NaN      0
# 45464  False                             NaN      0
# 45465  False                             NaN      0
#
#                               genres      id original_language  \
# 2                     Romance|Comedy   15602                en
# 4                             Comedy   11862                en
# 7      Action|Adventure|Drama|Family   45325                en
# 11                     Comedy|Horror   12110                en
# 12        Family|Animation|Adventure   21032                en
# ...                              ...     ...               ...
# 45461                   Drama|Family  439050                fa
# 45462                          Drama  111109                tl
# 45463          Action|Drama|Thriller   67758                en
# 45464                                 227506                en
# 45465                                 461257                en
#
#                     original_title  \
# 2                 Grumpier Old Men
# 4      Father of the Bride Part II
# 7                     Tom and Huck
# 11     Dracula: Dead and Loving It
# 12                           Balto
# ...                            ...
# 45461                      رگ خواب
# 45462          Siglo ng Pagluluwal
# 45463                     Betrayal
# 45464          Satana likuyushchiy
# 45465                     Queerama
#
#                                                 overview  popularity  \
# 2      A family wedding reignites the ancient feud be...   11.712900
# 4      Just when George Banks has recovered from his ...    8.387519
# 7      A mischievous young boy, Tom Sawyer, witnesses...    2.561161
# 11     When a lawyer shows up at the vampire's doorst...    5.430331
# 12     An outcast half-wolf risks his life to prevent...   12.140733
# ...                                                  ...         ...
# 45461        Rising and falling between a man and woman.    0.072051
# 45462  An artist struggles to finish his work while a...    0.178241
# 45463  When one of her hits goes wrong, a professiona...    0.903007
# 45464  In a small town live two brothers, one a minis...    0.003503
# 45465  50 years after decriminalisation of homosexual...    0.163015
#
#                                     production_companies  \
# 2                            Warner Bros.|Lancaster Gate
# 4              Sandollar Productions|Touchstone Pictures
# 7                                   Walt Disney Pictures
# 11     Columbia Pictures|Castle Rock Entertainment|En...
# 12     Universal Pictures|Amblin Entertainment|Amblim...
# ...                                                  ...
# 45461
# 45462                                        Sine Olivia
# 45463                            American World Pictures
# 45464                                          Yermoliev
# 45465
#
#                   production_countries release_date     revenue  runtime  \
# 2             United States of America   1995-12-22         0.0    101.0
# 4             United States of America   1995-02-10  76578911.0    106.0
# 7             United States of America   1995-12-22         0.0     97.0
# 11     France|United States of America   1995-12-22         0.0     88.0
# 12            United States of America   1995-12-22  11348324.0     78.0
# ...                                ...          ...         ...      ...
# 45461                             Iran          NaN         0.0     90.0
# 45462                      Philippines   2011-11-17         0.0    360.0
# 45463         United States of America   2003-08-01         0.0     90.0
# 45464                           Russia   1917-10-21         0.0     87.0
# 45465                   United Kingdom   2017-06-09         0.0     75.0
#
#                                         spoken_languages    status  \
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 7      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 11     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 12              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 2      Still Yelling. Still Fighting. Still Ready for...
# 4      Just When His World Is Back To Normal... He's ...
# 7                                 The Original Bad Boys.
# 11                                                   NaN
# 12                        Part Dog. Part Wolf. All Hero.
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video  vote_average  vote_count
# 2                 Grumpier Old Men  False           6.5        92.0
# 4      Father of the Bride Part II  False           5.7       173.0
# 7                     Tom and Huck  False           5.4        45.0
# 11     Dracula: Dead and Loving It  False           5.7       210.0
# 12                           Balto  False           7.1       423.0
# ...                            ...    ...           ...         ...
# 45461                       Subdue  False           4.0         1.0
# 45462          Century of Birthing  False           9.0         3.0
# 45463                     Betrayal  False           3.8         6.0
# 45464             Satan Triumphant  False           0.0         0.0
# 45465                     Queerama  False           0.0         0.0
#
# [36509 rows x 21 columns]

# %%
#cupturing strings in budget column
string_budget = [x for x in data['budget'] if re.search('[a-zA-Z]', x)]

# %%
string_budget
# Out:
# ['/ff9qCepilowshEtG2GYWwzt2bs4.jpg',
#  '/zV8bHuSL6WXoD6FWogP9j4x80bL.jpg',
#  '/zaSf5OG7V8X8gqFvly88zDdRm46.jpg']

# %%
for i in string_budget:
    data['budget'].replace(i,np.nan,inplace=True)

# %%
data['budget'] = data['budget'].astype(float)

# %%
data['budget'].replace(0.0,np.nan,inplace=True)

# %%
data['release_date'] = pd.to_datetime(data['release_date'],errors='coerce')

# %%
data['release_date'].value_counts(ascending=False)
# Out:
# 2008-01-01    136
# 2009-01-01    121
# 2007-01-01    118
# 2005-01-01    111
# 2006-01-01    101
#              ...
# 1937-10-22      1
# 1948-07-14      1
# 1949-08-01      1
# 1957-09-26      1
# 1917-10-21      1
# Name: release_date, Length: 17321, dtype: int64

# %%
#ruffly same 0.0 as 'budget' for 'revenue' column as we dont know budget we cant know revenue i guess i will replace 0.0 with np.nan too
data['revenue'].value_counts(ascending=False)
# Out:
# 0.0           37986
# 12000000.0       20
# 11000000.0       19
# 10000000.0       19
# 2000000.0        18
#               ...
# 36565280.0        1
# 439564.0          1
# 35610100.0        1
# 10217873.0        1
# 1413000.0         1
# Name: revenue, Length: 6863, dtype: int64

# %%
data['revenue'].replace(0.0,np.nan,inplace=True)

# %%
# runtime for 1558 is 0.0 and this is not valid also so i will replace these with np.nan also 
data['runtime'].value_counts(ascending=False)
# Out:
# 90.0     2553
# 0.0      1540
# 100.0    1468
# 95.0     1411
# 93.0     1213
#          ...
# 410.0       1
# 283.0       1
# 238.0       1
# 566.0       1
# 780.0       1
# Name: runtime, Length: 353, dtype: int64

# %%
data['runtime'].replace(0.0,np.nan,inplace=True)

# %%
data['spoken_languages'].value_counts(ascending=False)
# Out:
# [{'iso_639_1': 'en', 'name': 'English'}]                                                                                                                                                                   22383
# []                                                                                                                                                                                                          3790
# [{'iso_639_1': 'fr', 'name': 'Français'}]                                                                                                                                                                   1851
# [{'iso_639_1': 'ja', 'name': '日本語'}]                                                                                                                                                                        1288
# [{'iso_639_1': 'it', 'name': 'Italiano'}]                                                                                                                                                                   1218
#                                                                                                                                                                                                            ...
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'et', 'name': 'Eesti'}, {'iso_639_1': 'fr', 'name': 'Français'}]                                                                                        1
# [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso_639_1': 'fi', 'name': 'suomi'}, {'iso_639_1': 'fr', 'name': 'Français'}, {'iso_639_1': 'ru', 'name': 'Pусский'}, {'iso_639_1': 'en', 'name': 'English'}]        1
# [{'iso_639_1': 'bs', 'name': 'Bosanski'}, {'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'it', 'name': 'Italiano'}]                                                                                     1
# [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'ta', 'name': 'தமிழ்'}, {'iso_639_1': 'te', 'name': 'తెలుగు'}]                                                                                          1
# [{'iso_639_1': 'ff', 'name': 'Fulfulde'}, {'iso_639_1': 'en', 'name': 'English'}]                                                                                                                              1
# Name: spoken_languages, Length: 1931, dtype: int64

# %%
data['spoken_languages'][1]
# Out:
# "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]"

# %%
data['spoken_languages'] = data['spoken_languages'].apply(lambda x : handle_json(x))

# %%
data['spoken_languages'] = data['spoken_languages'].apply(lambda x : '|'.join(i['name'] for i in x) if isinstance(x,list) else 'missing')

# %%
data['status'].value_counts(ascending=False)
# Out:
# Released           44950
# Rumored              229
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %%
# for tagline i can replace - and blancks with missing 
data['tagline'].value_counts(ascending=False)
# Out:
# Based on a true story.                                        7
# Be careful what you wish for.                                 4
# -                                                             4
# Trust no one.                                                 4
# Some doors should never be opened.                            3
#                                                              ..
# Play it. Sing it. Shout it. Feel it.                          1
# If It's On TV, It Must Be The Truth.                          1
# "I LOVE YOU BABY, BUT MY WIFE JUST REFUSES TO UNDERSTAND!"    1
# That Joyous New Musical !                                     1
# A deadly game of wits.                                        1
# Name: tagline, Length: 20277, dtype: int64

# %%
tagline_replace = ['-' , '']
for i in tagline_replace:
    data['tagline'].replace(i,'missing',inplace=True)

# %%
data['title'].value_counts(ascending=False)
# Out:
# Cinderella              11
# Alice in Wonderland      9
# Hamlet                   9
# Beauty and the Beast     8
# Les Misérables           8
#                         ..
# The Exploding Girl       1
# Prodigal Sons            1
# Seven Angry Men          1
# 06/05                    1
# Queerama                 1
# Name: title, Length: 42212, dtype: int64

# %%
data['video'].value_counts(ascending=False)
# Out:
# False    45302
# True        92
# Name: video, dtype: int64

# %%
# vote average for 2998 0.0 !!
data['vote_average'].value_counts(ascending=False)
# Out:
# 0.0    2932
# 6.0    2468
# 5.0    2001
# 7.0    1886
# 6.5    1722
#        ...
# 9.4       3
# 9.6       1
# 9.8       1
# 0.7       1
# 1.1       1
# Name: vote_average, Length: 92, dtype: int64

# %%
# note 'genres' , 'production_companies' and 'spoken_languages' have blancks deal with this 
data[(data['vote_average']==0.0)].head(30)
# Out:
#      adult belongs_to_collection  budget                         genres  \
# 83   False                   NaN     NaN                        missing
# 107  False                   NaN     NaN                          Crime
# 126  False                   NaN     NaN                        missing
# 132  False                   NaN     NaN              Music|Documentary
# 137  False                   NaN     NaN                        missing
# 164  False                   NaN     NaN                    Drama|Crime
# 280  False                   NaN     NaN    Action|Thriller|Crime|Drama
# 390  False                   NaN     NaN                        missing
# 395  False                   NaN     NaN                 Thriller|Drama
# 397  False                   NaN     NaN                         Comedy
# 554  False                   NaN     NaN                        missing
# 565  False                   NaN     NaN  TV Movie|Drama|Romance|Comedy
# 566  False                   NaN     NaN                  Drama|Romance
# 570  False                   NaN     NaN                         Comedy
# 635  False                   NaN     NaN                         Comedy
# 644  False                   NaN     NaN                          Drama
# 645  False                   NaN     NaN                          Drama
# 648  False                   NaN     NaN                        missing
# 661  False                   NaN     NaN                        missing
# 671  False                   NaN     NaN                        missing
# 685  False                   NaN     NaN                        missing
# 707  False                   NaN     NaN                  Drama|Foreign
# 711  False                   NaN     NaN                        missing
# 722  False                   NaN     NaN                         Comedy
# 726  False                   NaN     NaN                   Comedy|Drama
# 731  False                   NaN     NaN                      Drama|War
# 734  False                   NaN     NaN                        missing
# 741  False                   NaN     NaN                    Documentary
# 750  False                   NaN     NaN                          Drama
# 756  False                   NaN     NaN                        missing
#
#          id original_language                        original_title  \
# 83   188588                en           Last Summer in the Hamptons
# 107   96357                en          Headless Body in Topless Bar
# 126  290157                en                        Jupiter's Wife
# 132  124636                en                         Sonic Outlaws
# 137  124639                en                                Target
# 164  259209                en                         Feast of July
# 280  109560                en                          New York Cop
# 390  267188                en                          Desert Winds
# 395  291731                en                                Homage
# 397  203119                en                           Open Season
# 554  218473                en             The Beans of Egypt, Maine
# 565   53185                en                 Wide Eyed and Legless
# 566   95743                en                       Foreign Student
# 570  349394                en                             À la mode
# 635  339428                de                         Happy Weekend
# 644  278978                de             Und keiner weint mir nach
# 645  124625                de                   My Mother's Courage
# 648   70934                en                       Billy's Holiday
# 661  318177                en                            Tarantella
# 671  185191                en                       L'oeil de Vichy
# 685  277270                en                  To Cross the Rubicon
# 707  131232                en                             Due Amici
# 711  365371                en  War Stories Our Mother Never Told Us
# 722  314352                de                             Honigmond
# 726  124613                en                   Brothers in Trouble
# 731  245268                en               The Man from Down Under
# 734  215107                en                 Vermont Is for Lovers
# 741   85778                en       Maya Lin: A Strong Clear Vision
# 750  124633                sr                          Tuđa Amerika
# 756  188589                en                             Babyfever
#
#                                               overview  popularity  \
# 83   Filmed entirely on location in East Hampton, L...    0.531159
# 107  An ex-con holds a group of people hostage in a...    0.001346
# 126  Michel Negroponte, a documentary filmmaker, me...    0.001178
# 132  Within days after the release of Negativland's...    0.001838
# 137   A subtle yet violent commentary on feudal lords.    0.001205
# 164  After an abandoned young woman in late 19th Ce...    0.523575
# 280  Allegedly based on a true story, this film fol...    0.004537
# 390  Jackie and Eugene are joined by a mystical win...    0.251223
# 395  The young caretaker at the estate of a reclusi...    0.014925
# 397  When the television ratings machines suddenly ...    0.012456
# 554  The Beans are poor, proud, hated by all, but a...    0.382470
# 565  Diana and Deric have an ideal marriage: they t...    0.000150
# 566  A French football playing exchange student fal...    0.002789
# 570  Fausto enters an orphanage and is initially bu...    0.000082
# 635                                                NaN    0.002229
# 644                                                NaN    0.439989
# 645  The deportation of 4000 Jews from Budapest to ...    0.622885
# 648  This movie is all about a normal guy called Bi...    0.002444
# 661  Academy Award winner Mira Sorvino plays photog...    0.001662
# 671  Directed by French filmmaker Claude Chabrol, t...    0.004117
# 685  Kendall (Patricia Royce) just got dumped by he...    0.006854
# 707  Two Sicilian friends, Nunzio and Pino, share t...    0.003949
# 711  Seven New Zealand women speak about their live...    0.005625
# 722                                      German Comedy    0.652621
# 726  Amir is an illegal Pakistani immigrant smuggle...    0.594716
# 731  An Australian blowhard raises two orphaned chi...    0.068254
# 734  Vermont is for Lovers is an independently prod...    0.750000
# 741  A film about the work of the artist most famou...    0.001608
# 750  This tale takes place in a bar. The Spanish Al...    0.099602
# 756  Gena is an average woman who is torn between h...    0.001687
#
#                                   production_companies  \
# 83                                             missing
# 107                                            missing
# 126                                            missing
# 132                                            missing
# 137                                            missing
# 164     Touchstone Pictures|Merchant Ivory Productions
# 280                 TOEI|Distant Justice Joint Venture
# 390                                            missing
# 395               Skyline Entertainment Partners|Arrow
# 397  Home Box Office (HBO)|Frozen Rope Productions ...
# 554                                            missing
# 565                                            missing
# 566                                            missing
# 570                                            missing
# 635                            Senator Film Produktion
# 644                                            missing
# 645                                            missing
# 648                                            missing
# 661                                            missing
# 671                                            missing
# 685                                            missing
# 707                                            missing
# 711                                            missing
# 722                       Roxy Film|MTM Cineteve|Pro 7
# 726                                     Renegade Films
# 731                          Metro-Goldwyn-Mayer (MGM)
# 734                                            missing
# 741                                            missing
# 750  MACT Productions|Canal+|Stefi 2|Lichtblick Fil...
# 756                                            missing
#
#                             production_countries release_date  revenue  \
# 83                                       missing   1995-11-22      NaN
# 107                                      missing   1995-05-20      NaN
# 126                                      missing   1995-01-01      NaN
# 132                     United States of America   1995-08-01      NaN
# 137                                      missing   1995-08-01      NaN
# 164                                      missing   1995-10-12      NaN
# 280               Japan|United States of America   1993-08-14      NaN
# 390                                      missing   1997-12-31      NaN
# 395                     United States of America   1995-05-03      NaN
# 397                     United States of America   1996-05-03      NaN
# 554                                      missing   1994-01-01      NaN
# 565                                      missing   1993-09-05      NaN
# 566                                      missing   1994-07-29      NaN
# 570                                      missing   1993-09-10      NaN
# 635                                      Germany   1996-03-14  65335.0
# 644                                      Germany   1996-02-29      NaN
# 645       United Kingdom|Germany|Ireland|Austria   1995-09-12      NaN
# 648                                      missing   1995-07-26      NaN
# 661                                      missing   1996-03-15      NaN
# 671                                      missing   1993-05-20      NaN
# 685                                      missing   1991-01-01      NaN
# 707                                        Italy   2002-03-20      NaN
# 711                                      missing          NaT      NaN
# 722                                      Germany   1996-04-11      NaN
# 726                               United Kingdom   1995-08-23      NaN
# 731                     United States of America   1943-08-04      NaN
# 734                                      missing          NaT      NaN
# 741                     United States of America   1995-11-10      NaN
# 750  Serbia|Greece|United Kingdom|France|Germany   1995-09-09      NaN
# 756                                      missing   1994-05-04      NaN
#
#      runtime   spoken_languages    status  \
# 83     108.0            missing  Released
# 107    110.0            missing  Released
# 126     87.0            missing  Released
# 132     87.0            English  Released
# 137    122.0            missing  Released
# 164    116.0            English  Released
# 280     93.0  English|广州话 / 廣州話  Released
# 390     97.0            missing  Released
# 395     97.0            English  Released
# 397     97.0            English  Released
# 554      NaN            missing  Released
# 565    102.0            English  Released
# 566     90.0            English  Released
# 570     82.0            missing  Released
# 635      NaN            Deutsch  Released
# 644      NaN            Deutsch  Released
# 645     93.0    English|Deutsch  Released
# 648     92.0            missing  Released
# 661    100.0            English  Released
# 671    110.0            missing  Released
# 685      NaN            missing  Released
# 707     86.0           Italiano  Released
# 711     95.0            missing  Released
# 722     92.0            Deutsch  Released
# 726    102.0            English  Released
# 731    103.0            English  Released
# 734     88.0            missing  Released
# 741    105.0            English  Released
# 750     96.0     English|Srpski  Released
# 756    109.0            missing  Released
#
#                                                tagline  \
# 83                                                 NaN
# 107                                                NaN
# 126                       A Haunting Real Life Mystery
# 132                                                NaN
# 137                                                NaN
# 164                  There is no escape from the past.
# 280  The toughest city in the world deserves the to...
# 390                            It began with a whisper
# 395  He would sacrifice everything for her...even her.
# 397                                                NaN
# 554                                                NaN
# 565                                                NaN
# 566                                                NaN
# 570                                                NaN
# 635                                                NaN
# 644                                                NaN
# 645                                                NaN
# 648       As of today, he's not the man he used to be!
# 661                                                NaN
# 671                                                NaN
# 685                                                NaN
# 707                                                NaN
# 711                                                NaN
# 722                                                NaN
# 726                                                NaN
# 731                            THRILLS!  FUN!  ACTION!
# 734                                                NaN
# 741  The story of The Vietnam Veterans Memorial and...
# 750                Two friends, two worlds, one dream.
# 756          For those who hear their clock ticking...
#
#                                     title  video  vote_average  vote_count
# 83            Last Summer in the Hamptons  False           0.0         0.0
# 107          Headless Body in Topless Bar  False           0.0         0.0
# 126                        Jupiter's Wife  False           0.0         0.0
# 132                         Sonic Outlaws  False           0.0         0.0
# 137                                Target  False           0.0         0.0
# 164                         Feast of July  False           0.0         0.0
# 280                          New York Cop  False           0.0         0.0
# 390                          Desert Winds  False           0.0         0.0
# 395                                Homage  False           0.0         0.0
# 397                           Open Season  False           0.0         0.0
# 554             The Beans of Egypt, Maine  False           0.0         1.0
# 565                 Wide Eyed and Legless  False           0.0         0.0
# 566                       Foreign Student  False           0.0         0.0
# 570                             À la mode  False           0.0         0.0
# 635                         Happy Weekend  False           0.0         0.0
# 644             Und keiner weint mir nach  False           0.0         0.0
# 645                   My Mother's Courage  False           0.0         0.0
# 648                       Billy's Holiday  False           0.0         0.0
# 661                            Tarantella  False           0.0         0.0
# 671                      The Eye of Vichy  False           0.0         0.0
# 685                  To Cross the Rubicon  False           0.0         0.0
# 707                           Two Friends  False           0.0         0.0
# 711  War Stories Our Mother Never Told Us  False           0.0         0.0
# 722                             Honeymoon  False           0.0         0.0
# 726                   Brothers in Trouble  False           0.0         0.0
# 731               The Man from Down Under  False           0.0         0.0
# 734                 Vermont Is for Lovers  False           0.0         0.0
# 741       Maya Lin: A Strong Clear Vision  False           0.0         0.0
# 750                Someone Else's America  False           0.0         0.0
# 756                             Babyfever  False           0.0         0.0

# %%
data['production_companies'].replace('','missing',inplace=True)
data['genres'].replace('','missing',inplace=True)
data['spoken_languages'].replace('','missing',inplace=True)

# %%
#both vote average and vote count 0 to the same rows obersvations 
data.groupby(['vote_average'])['vote_count'].count()
# Out:
# vote_average
# 0.0     2932
# 0.5       13
# 0.7        1
# 1.0      105
# 1.1        1
#         ...
# 9.4        3
# 9.5       18
# 9.6        1
# 9.8        1
# 10.0     190
# Name: vote_count, Length: 92, dtype: int64

# %% [markdown]
# inspect why vote average of these movies 0

# %%
data['vote_count'].value_counts(ascending=False)
# Out:
# 1.0       3264
# 2.0       3132
# 0.0       2899
# 3.0       2787
# 4.0       2480
#           ...
# 2755.0       1
# 1187.0       1
# 4200.0       1
# 3322.0       1
# 2712.0       1
# Name: vote_count, Length: 1820, dtype: int64

# %% [markdown]
# inspect why some movies have vote count 1

# %%
data['budget'].isna().sum()
# Out:
# 36512

# %% [markdown]
# scale revenue and budget

# %%
data['budget'] = data['budget']/1000000

# %%
data['revenue'] = data['revenue']/1000000

# %%
os.chdir(r'C:\Users\saadb\recommendation_project')

# %%
data.to_csv(path_or_buf='jupyter_notebook/datasets/movies_cleaned.csv',index=False)

# %%
df = pd.read_csv('jupyter_notebook/datasets/movies_cleaned.csv')
df.head(3)
# Out:
#    adult      belongs_to_collection  budget                    genres     id  \
# 0  False       Toy Story Collection    30.0   Animation|Comedy|Family    862
# 1  False                        NaN    65.0  Adventure|Fantasy|Family   8844
# 2  False  Grumpy Old Men Collection     NaN            Romance|Comedy  15602
#
#   original_language    original_title  \
# 0                en         Toy Story
# 1                en           Jumanji
# 2                en  Grumpier Old Men
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
# 2                        Warner Bros.|Lancaster Gate
#
#        production_countries release_date     revenue  runtime  \
# 0  United States of America   1995-10-30  373.554033     81.0
# 1  United States of America   1995-12-15  262.797249    104.0
# 2  United States of America   1995-12-22         NaN    101.0
#
#    spoken_languages    status  \
# 0           English  Released
# 1  English|Français  Released
# 2           English  Released
#
#                                              tagline             title  video  \
# 0                                                NaN         Toy Story  False
# 1          Roll the dice and unleash the excitement!           Jumanji  False
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
